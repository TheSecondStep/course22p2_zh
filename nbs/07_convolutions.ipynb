# %%
#|default_exp conv

# %% [markdown]
# # Convolutions

# %%
import sys
sys.path.insert(0, '/app/data/deeplearning/course22p2_zh')

# %%
#|export
import torch
from torch import nn

from torch.utils.data import default_collate
from typing import Mapping

from miniai.training import *
from miniai.datasets import *

# %%
import pickle,gzip,math,os,time,shutil,torch,matplotlib as mpl, numpy as np
import pandas as pd,matplotlib.pyplot as plt
from pathlib import Path
from torch import tensor

from torch.utils.data import DataLoader
from typing import Mapping

# %%
mpl.rcParams['image.cmap'] = 'gray'

# %%
path_data = Path('data')
path_gz = path_data/'mnist.pkl.gz'
with gzip.open(path_gz, 'rb') as f: ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding='latin-1')
x_train, y_train, x_valid, y_valid = map(tensor, [x_train, y_train, x_valid, y_valid])
# Out:
# /tmp/ipykernel_4052/2645617309.py:3: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   with gzip.open(path_gz, 'rb') as f: ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding='latin-1')

# %% [markdown]
# In the context of an image, a feature is a visually distinctive attribute. For example, the number 7 is characterized by a horizontal edge near the top of the digit, and a top-right to bottom-left diagonal edge underneath that.
#
# It turns out that finding the edges in an image is a very common task in computer vision, and is surprisingly straightforward. To do it, we use a *convolution*. A convolution requires nothing more than multiplication, and addition.

# %% [markdown]
# ### Understanding the Convolution Equations

# %% [markdown]
# To explain the math behind convolutions, fast.ai student Matt Kleinsmith came up with the very clever idea of showing [CNNs from different viewpoints](https://medium.com/impactai/cnns-from-different-viewpoints-fab7f52d159c).
#
# Here's the input:

# %% [markdown]
# ![](images/att_00032.png)

# %% [markdown]
# Here's our kernel:

# %% [markdown]
# ![](images/att_00033.png)

# %% [markdown]
# Since the filter fits in the image four times, we have four results:

# %% [markdown]
# ![](images/att_00034.png)

# %% [markdown]
# ![](images/att_00035.png)

# %% [markdown]
# ![](images/att_00036.png)

# %%
x_imgs = x_train.view(-1,28,28)
xv_imgs = x_valid.view(-1,28,28)

# %%
x_imgs.shape
# Out:
# torch.Size([50000, 28, 28])

# %%
mpl.rcParams['figure.dpi'] = 30

# %%
im3 = x_imgs[7]
show_image(im3);

# %%
top_edge = tensor([[-1,-1,-1],
                   [ 0, 0, 0],
                   [ 1, 1, 1]]).float()

# %% [markdown]
# We're going to call this our kernel (because that's what fancy computer vision researchers call these).

# %%
show_image(top_edge, noframe=False);

# %% [markdown]
# The filter will take any window of size 3×3 in our images, and if we name the pixel values like this:
#
# $$\begin{matrix} a1 & a2 & a3 \\ a4 & a5 & a6 \\ a7 & a8 & a9 \end{matrix}$$
#
# it will return $-a1-a2-a3+a7+a8+a9$.

# %%
df = pd.DataFrame(im3[:13,:23])

# %%
df.style.format(precision=2).set_properties(**{'font-size':'7pt'}).background_gradient('Greys')
# Out:
# <style type="text/css">
# #T_9750d_row0_col0, #T_9750d_row0_col1, #T_9750d_row0_col2, #T_9750d_row0_col3, #T_9750d_row0_col4, #T_9750d_row0_col5, #T_9750d_row0_col6, #T_9750d_row0_col7, #T_9750d_row0_col8, #T_9750d_row0_col9, #T_9750d_row0_col10, #T_9750d_row0_col11, #T_9750d_row0_col12, #T_9750d_row0_col13, #T_9750d_row0_col14, #T_9750d_row0_col15, #T_9750d_row0_col16, #T_9750d_row0_col17, #T_9750d_row0_col18, #T_9750d_row0_col19, #T_9750d_row0_col20, #T_9750d_row0_col21, #T_9750d_row0_col22, #T_9750d_row1_col0, #T_9750d_row1_col1, #T_9750d_row1_col2, #T_9750d_row1_col3, #T_9750d_row1_col4, #T_9750d_row1_col5, #T_9750d_row1_col6, #T_9750d_row1_col7, #T_9750d_row1_col8, #T_9750d_row1_col9, #T_9750d_row1_col10, #T_9750d_row1_col11, #T_9750d_row1_col12, #T_9750d_row1_col13, #T_9750d_row1_col14, #T_9750d_row1_col15, #T_9750d_row1_col16, #T_9750d_row1_col17, #T_9750d_row1_col18, #T_9750d_row1_col19, #T_9750d_row1_col20, #T_9750d_row1_col21, #T_9750d_row1_col22, #T_9750d_row2_col0, #T_9750d_row2_col1, #T_9750d_row2_col2, #T_9750d_row2_col3, #T_9750d_row2_col4, #T_9750d_row2_col5, #T_9750d_row2_col6, #T_9750d_row2_col7, #T_9750d_row2_col8, #T_9750d_row2_col9, #T_9750d_row2_col10, #T_9750d_row2_col11, #T_9750d_row2_col12, #T_9750d_row2_col13, #T_9750d_row2_col14, #T_9750d_row2_col15, #T_9750d_row2_col16, #T_9750d_row2_col17, #T_9750d_row2_col18, #T_9750d_row2_col19, #T_9750d_row2_col20, #T_9750d_row2_col21, #T_9750d_row2_col22, #T_9750d_row3_col0, #T_9750d_row3_col1, #T_9750d_row3_col2, #T_9750d_row3_col3, #T_9750d_row3_col4, #T_9750d_row3_col5, #T_9750d_row3_col6, #T_9750d_row3_col7, #T_9750d_row3_col8, #T_9750d_row3_col9, #T_9750d_row3_col10, #T_9750d_row3_col11, #T_9750d_row3_col12, #T_9750d_row3_col13, #T_9750d_row3_col14, #T_9750d_row3_col15, #T_9750d_row3_col16, #T_9750d_row3_col17, #T_9750d_row3_col18, #T_9750d_row3_col19, #T_9750d_row3_col20, #T_9750d_row3_col21, #T_9750d_row3_col22, #T_9750d_row4_col0, #T_9750d_row4_col1, #T_9750d_row4_col2, #T_9750d_row4_col3, #T_9750d_row4_col4, #T_9750d_row4_col5, #T_9750d_row4_col6, #T_9750d_row4_col7, #T_9750d_row4_col8, #T_9750d_row4_col9, #T_9750d_row4_col10, #T_9750d_row4_col11, #T_9750d_row4_col12, #T_9750d_row4_col13, #T_9750d_row4_col14, #T_9750d_row4_col15, #T_9750d_row4_col16, #T_9750d_row4_col17, #T_9750d_row4_col18, #T_9750d_row4_col19, #T_9750d_row4_col20, #T_9750d_row4_col21, #T_9750d_row4_col22, #T_9750d_row5_col0, #T_9750d_row5_col1, #T_9750d_row5_col2, #T_9750d_row5_col3, #T_9750d_row5_col4, #T_9750d_row5_col5, #T_9750d_row5_col6, #T_9750d_row5_col7, #T_9750d_row5_col8, #T_9750d_row5_col9, #T_9750d_row5_col10, #T_9750d_row5_col22, #T_9750d_row6_col0, #T_9750d_row6_col1, #T_9750d_row6_col2, #T_9750d_row6_col3, #T_9750d_row6_col4, #T_9750d_row6_col5, #T_9750d_row6_col6, #T_9750d_row6_col7, #T_9750d_row6_col8, #T_9750d_row7_col0, #T_9750d_row7_col1, #T_9750d_row7_col2, #T_9750d_row7_col3, #T_9750d_row7_col4, #T_9750d_row7_col5, #T_9750d_row7_col6, #T_9750d_row7_col7, #T_9750d_row7_col8, #T_9750d_row8_col0, #T_9750d_row8_col1, #T_9750d_row8_col2, #T_9750d_row8_col3, #T_9750d_row8_col4, #T_9750d_row8_col5, #T_9750d_row8_col6, #T_9750d_row8_col7, #T_9750d_row8_col8, #T_9750d_row9_col0, #T_9750d_row9_col1, #T_9750d_row9_col2, #T_9750d_row9_col3, #T_9750d_row9_col4, #T_9750d_row9_col5, #T_9750d_row9_col6, #T_9750d_row9_col7, #T_9750d_row9_col8, #T_9750d_row9_col13, #T_9750d_row9_col14, #T_9750d_row9_col15, #T_9750d_row9_col16, #T_9750d_row10_col0, #T_9750d_row10_col1, #T_9750d_row10_col2, #T_9750d_row10_col3, #T_9750d_row10_col4, #T_9750d_row10_col5, #T_9750d_row10_col6, #T_9750d_row10_col7, #T_9750d_row10_col8, #T_9750d_row10_col9, #T_9750d_row10_col10, #T_9750d_row10_col11, #T_9750d_row10_col12, #T_9750d_row10_col13, #T_9750d_row10_col14, #T_9750d_row10_col15, #T_9750d_row10_col16, #T_9750d_row10_col22, #T_9750d_row11_col0, #T_9750d_row11_col1, #T_9750d_row11_col2, #T_9750d_row11_col3, #T_9750d_row11_col4, #T_9750d_row11_col5, #T_9750d_row11_col6, #T_9750d_row11_col7, #T_9750d_row11_col8, #T_9750d_row11 ...
#   font-size: 7pt;
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_9750d_row5_col11 {
#   font-size: 7pt;
#   background-color: #ececec;
#   color: #000000;
# }
# #T_9750d_row5_col12 {
#   font-size: 7pt;
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_9750d_row5_col13 {
#   font-size: 7pt;
#   background-color: #b0b0b0;
#   color: #000000;
# }
# #T_9750d_row5_col14, #T_9750d_row5_col15, #T_9750d_row5_col16, #T_9750d_row5_col17, #T_9750d_row5_col18, #T_9750d_row5_col19, #T_9750d_row6_col13, #T_9750d_row6_col20, #T_9750d_row7_col9, #T_9750d_row7_col10, #T_9750d_row7_col11, #T_9750d_row7_col12, #T_9750d_row7_col13, #T_9750d_row7_col20, #T_9750d_row7_col21, #T_9750d_row7_col22, #T_9750d_row8_col10, #T_9750d_row8_col11, #T_9750d_row8_col20, #T_9750d_row8_col21, #T_9750d_row8_col22, #T_9750d_row9_col20, #T_9750d_row10_col20, #T_9750d_row11_col20 {
#   font-size: 7pt;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9750d_row5_col20 {
#   font-size: 7pt;
#   background-color: #626262;
#   color: #f1f1f1;
# }
# #T_9750d_row5_col21 {
#   font-size: 7pt;
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_9750d_row6_col9 {
#   font-size: 7pt;
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_9750d_row6_col10 {
#   font-size: 7pt;
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_9750d_row6_col11 {
#   font-size: 7pt;
#   background-color: #212121;
#   color: #f1f1f1;
# }
# #T_9750d_row6_col12 {
#   font-size: 7pt;
#   background-color: #1e1e1e;
#   color: #f1f1f1;
# }
# #T_9750d_row6_col14, #T_9750d_row7_col14 {
#   font-size: 7pt;
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_9750d_row6_col15, #T_9750d_row6_col16, #T_9750d_row6_col17, #T_9750d_row6_col18, #T_9750d_row6_col19, #T_9750d_row7_col15, #T_9750d_row7_col16, #T_9750d_row7_col17, #T_9750d_row7_col18, #T_9750d_row7_col19, #T_9750d_row8_col18, #T_9750d_row8_col19, #T_9750d_row9_col19, #T_9750d_row10_col19, #T_9750d_row11_col18, #T_9750d_row11_col19, #T_9750d_row12_col17, #T_9750d_row12_col18, #T_9750d_row12_col19 {
#   font-size: 7pt;
#   background-color: #010101;
#   color: #f1f1f1;
# }
# #T_9750d_row6_col21 {
#   font-size: 7pt;
#   background-color: #727272;
#   color: #f1f1f1;
# }
# #T_9750d_row6_col22 {
#   font-size: 7pt;
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_9750d_row8_col9 {
#   font-size: 7pt;
#   background-color: #777777;
#   color: #f1f1f1;
# }
# #T_9750d_row8_col12 {
#   font-size: 7pt;
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_9750d_row8_col13 {
#   font-size: 7pt;
#   background-color: #8f8f8f;
#   color: #f1f1f1;
# }
# #T_9750d_row8_col14, #T_9750d_row8_col15, #T_9750d_row8_col16 {
#   font-size: 7pt;
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_9750d_row8_col17, #T_9750d_row11_col17 {
#   font-size: 7pt;
#   background-color: #525252;
#   color: #f1f1f1;
# }
# #T_9750d_row9_col9 {
#   font-size: 7pt;
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_9750d_row9_col10, #T_9750d_row9_col11, #T_9750d_row9_col22 {
#   font-size: 7pt;
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_9750d_row9_col12 {
#   font-size: 7pt;
#   background-color: #f4f4f4;
#   color: #000000;
# }
# #T_9750d_row9_col17, #T_9750d_row11_col21 {
#   font-size: 7pt;
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_9750d_row9_col18 {
#   font-size: 7pt;
#   background-color: #1f1f1f;
#   color: #f1f1f1;
# }
# #T_9750d_row9_col21 {
#   font-size: 7pt;
#   background-color: #646464;
#   color: #f1f1f1;
# }
# #T_9750d_row10_col17 {
#   font-size: 7pt;
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_9750d_row10_col18 {
#   font-size: 7pt;
#   background-color: #0c0c0c;
#   color: #f1f1f1;
# }
# #T_9750d

# %%
(im3[3:6,14:17] * top_edge).sum()
# Out:
# tensor(2.9727)

# %%
(im3[7:10,14:17] * top_edge).sum()
# Out:
# tensor(-2.9570)

# %%
def apply_kernel(row, col, kernel): return (im3[row-1:row+2,col-1:col+2] * kernel).sum()

# %%
apply_kernel(4,15,top_edge)
# Out:
# tensor(2.9727)

# %% [markdown]
# ![](images/chapter9_nopadconv.svg)

# %%
[[(i,j) for j in range(5)] for i in range(5)]
# Out:
# [[(0, 0), (0, 1), (0, 2), (0, 3), (0, 4)],
#  [(1, 0), (1, 1), (1, 2), (1, 3), (1, 4)],
#  [(2, 0), (2, 1), (2, 2), (2, 3), (2, 4)],
#  [(3, 0), (3, 1), (3, 2), (3, 3), (3, 4)],
#  [(4, 0), (4, 1), (4, 2), (4, 3), (4, 4)]]

# %%
rng = range(1,27)
top_edge3 = tensor([[apply_kernel(i,j,top_edge) for j in rng] for i in rng])
show_image(top_edge3);

# %%
top_edge3.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 top_edge3.shape
#
# NameError: name 'top_edge3' is not defined

# %%
left_edge = tensor([[-1,0,1],
                    [-1,0,1],
                    [-1,0,1]]).float()

# %%
show_image(left_edge, noframe=False);

# %%
left_edge3 = tensor([[apply_kernel(i,j,left_edge) for j in rng] for i in rng])
show_image(left_edge3);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 left_edge3 = tensor([[apply_kernel(i,j,left_edge) for j in rng] for i in rng])
#       2 show_image(left_edge3);
#
# NameError: name 'rng' is not defined

# %% [markdown]
# ![](images/att_00028.png)

# %% [markdown]
# ### Convolutions in PyTorch

# %%
import torch.nn.functional as F
import torch

# %% [markdown]
# What to do if you have [2 months to complete your thesis](https://github.com/Yangqing/caffe/wiki/Convolution-in-Caffe:-a-memo)? Use [im2col](https://hal.inria.fr/inria-00112631/).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here's a sample [numpy implementation](https://github.com/3outeille/CNNumpy/blob/5394f13e7ed67a808a3e39fd381f168825d65ff5/src/fast/utils.py#L360).

# %%
inp = im3[None,None,:,:].float()
inp_unf = F.unfold(inp, (3,3))[0]
inp_unf.shape
# Out:
# torch.Size([9, 676])

# %%
w = left_edge.view(-1)
w.shape
# Out:
# torch.Size([9])

# %%
out_unf = w@inp_unf
out_unf.shape
# Out:
# torch.Size([676])

# %%
out = out_unf.view(26,26)
show_image(out);

# %%
# %timeit -n 1 tensor([[apply_kernel(i,j,left_edge) for j in rng] for i in rng]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 get_ipython().run_line_magic('timeit', '-n 1 tensor([[apply_kernel(i,j,left_edge) for j in rng] for i in rng]);')
#
# File /usr/local/lib/python3.12/timeit.py:208, in Timer.repeat(self, repeat, number)
#     206 r = []
#     207 for i in range(repeat):
# --> 208     t = self.timeit(number)
#     209     r.append(t)
#     210 return r
#
# File <magic-timeit>:1, in inner(_it, _timer)
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# NameError: name 'rng' is not defined

# %%
# %timeit -n 100 (w@F.unfold(inp, (3,3))[0]).view(26,26);
# Out:
# The slowest run took 15.14 times longer than the fastest. This could mean that an intermediate result is being cached.
# 119 μs ± 169 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n 100 F.conv2d(inp, left_edge[None,None])
# Out:
# 15.7 µs ± 1.06 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
diag1_edge = tensor([[ 0,-1, 1],
                     [-1, 1, 0],
                     [ 1, 0, 0]]).float()

# %%
show_image(diag1_edge, noframe=False);

# %%
diag2_edge = tensor([[ 1,-1, 0],
                     [ 0, 1,-1],
                     [ 0, 0, 1]]).float()

# %%
show_image(diag2_edge, noframe=False);

# %%
xb = x_imgs[:16][:,None]
xb.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
edge_kernels = torch.stack([left_edge, top_edge, diag1_edge, diag2_edge])[:,None]
edge_kernels.shape
# Out:
# torch.Size([4, 1, 3, 3])

# %%
batch_features = F.conv2d(xb, edge_kernels)
batch_features.shape
# Out:
# torch.Size([16, 4, 26, 26])

# %% [markdown]
# The output shape shows we gave 64 images in the mini-batch, 4 kernels, and 26×26 edge maps (we started with 28×28 images, but lost one pixel from each side as discussed earlier). We can see we get the same results as when we did this manually:

# %%
img0 = xb[1,0]
show_image(img0);

# %%
show_images([batch_features[1,i] for i in range(4)])

# %% [markdown]
# ### Strides and Padding

# %% [markdown]
# With appropriate padding, we can ensure that the output activation map is the same size as the original image.

# %% [markdown]
# ![](images/chapter9_padconv.svg)

# %% [markdown]
# With a 5×5 input, 4×4 kernel, and 2 pixels of padding, we end up with a 6×6 activation map.

# %% [markdown]
# ![](images/att_00029.png)

# %% [markdown]
# If we add a kernel of size `ks` by `ks` (with `ks` an odd number), the necessary padding on each side to keep the same shape is `ks//2`.
#
# We could move over two pixels after each kernel application. This is known as a *stride-2* convolution.

# %% [markdown]
# ![](images/att_00030.png)

# %% [markdown]
# ## Creating the CNN

# %%
n,m = x_train.shape
c = y_train.max()+1
nh = 50

# %%
model = nn.Sequential(nn.Linear(m,nh), nn.ReLU(), nn.Linear(nh,10))

# %%
broken_cnn = nn.Sequential(
    nn.Conv2d(1,30, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.Conv2d(30,10, kernel_size=3, padding=1)
)

# %%
broken_cnn(xb).shape
# Out:
# torch.Size([16, 10, 28, 28])

# %%
#|export
def conv(ni, nf, ks=3, stride=2, act=True):
    res = nn.Conv2d(ni, nf, stride=stride, kernel_size=ks, padding=ks//2)
    if act: res = nn.Sequential(res, nn.ReLU())
    return res

# %% [markdown]
# Refactoring parts of your neural networks like this makes it much less likely you'll get errors due to inconsistencies in your architectures, and makes it more obvious to the reader which parts of your layers are actually changing.

# %%
simple_cnn = nn.Sequential(
    conv(1 ,4),            #14x14
    conv(4 ,8),            #7x7
    conv(8 ,16),           #4x4
    conv(16,16),           #2x2
    conv(16,10, act=False), #1x1
    nn.Flatten(),
)

# %%
simple_cnn(xb).shape
# Out:
# torch.Size([16, 10])

# %%
x_imgs = x_train.view(-1,1,28,28)
xv_imgs = x_valid.view(-1,1,28,28)
train_ds,valid_ds = Dataset(x_imgs, y_train),Dataset(xv_imgs, y_valid)

# %%
#|export
def_device = 'mps' if torch.backends.mps.is_available() else 'cuda' if torch.cuda.is_available() else 'cpu'

def to_device(x, device=def_device):
    if isinstance(x, torch.Tensor): return x.to(device)
    if isinstance(x, Mapping): return {k:v.to(device) for k,v in x.items()}
    return type(x)(to_device(o, device) for o in x)

def collate_device(b): return to_device(default_collate(b))

# %%
from torch import optim

bs = 256
lr = 0.4
train_dl,valid_dl = get_dls(train_ds, valid_ds, bs, collate_fn=collate_device)
opt = optim.SGD(simple_cnn.parameters(), lr=lr)

# %%
loss,acc = fit(5, simple_cnn.to(def_device), F.cross_entropy, opt, train_dl, valid_dl)
# Out:
# 0 0.3630618950843811 0.8875999997138977
# 1 0.16439641580581665 0.9496000003814697
# 2 0.24622697901725768 0.9316000004768371
# 3 0.25093305287361145 0.9335999998092651
# 4 0.13128829071521758 0.9618000007629395

# %%
opt = optim.SGD(simple_cnn.parameters(), lr=lr/4)
loss,acc = fit(5, simple_cnn.to(def_device), F.cross_entropy, opt, train_dl, valid_dl)
# Out:
# 0 0.08451943595409393 0.9756999996185303
# 1 0.08082638642787933 0.9777999995231629
# 2 0.08050601842403411 0.9778999995231629
# 3 0.08200360851287841 0.9773999995231628
# 4 0.08405050563812255 0.9761999994277955

# %% [markdown]
# ### Understanding Convolution Arithmetic

# %% [markdown]
# In an input of size `64x1x28x28` the axes are `batch,channel,height,width`. This is often represented as `NCHW` (where `N` refers to batch size). Tensorflow, on the other hand, uses `NHWC` axis order (aka "channels-last"). Channels-last is faster for many models, so recently it's become more common to see this as an option in PyTorch too.
#
# We have 1 input channel, 4 output channels, and a 3×3 kernel.

# %%
simple_cnn[0][0]
# Out:
# Conv2d(1, 4, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))

# %%
conv1 = simple_cnn[0][0]
conv1.weight.shape
# Out:
# torch.Size([4, 1, 3, 3])

# %%
conv1.bias.shape
# Out:
# torch.Size([4])

# %% [markdown]
# The *receptive field* is the area of an image that is involved in the calculation of a layer. *conv-example.xlsx* shows the calculation of two stride-2 convolutional layers using an MNIST digit. Here's what we see if we click on one of the cells in the *conv2* section, which shows the output of the second convolutional layer, and click *trace precedents*.

# %% [markdown]
# ![](images/att_00068.png)

# %% [markdown]
# The blue highlighted cells are its *precedents*—that is, the cells used to calculate its value. These cells are the corresponding 3×3 area of cells from the input layer (on the left), and the cells from the filter (on the right). Click *trace precedents* again:

# %% [markdown]
# ![](images/att_00069.png)

# %% [markdown]
# In this example, we have just two convolutional layers. We can see that a 7×7 area of cells in the input layer is used to calculate the single green cell in the Conv2 layer. This is the *receptive field*
#
# The deeper we are in the network (specifically, the more stride-2 convs we have before a layer), the larger the receptive field for an activation in that layer.

# %% [markdown]
# ## Color Images

# %% [markdown]
# A colour picture is a rank-3 tensor:

# %%
from torchvision.io import read_image

# %%
im = read_image('images/grizzly.jpg')
im.shape
# Out:
# torch.Size([3, 1000, 846])

# %%
show_image(im.permute(1,2,0));

# %%
_,axs = plt.subplots(1,3)
for bear,ax,color in zip(im,axs,('Reds','Greens','Blues')): show_image(255-bear, ax=ax, cmap=color)

# %% [markdown]
# ![](images/chapter9_rgbconv.svg)

# %% [markdown]
# These are then all added together, to produce a single number, for each grid location, for each output feature.

# %% [markdown]
# ![](images/chapter9_rgb_conv_stack.svg)

# %% [markdown]
# We have `ch_out` filters like this, so in the end, the result of our convolutional layer will be a batch of images with `ch_out` channels.

# %% [markdown]
# ## Export -

# %%
import nbdev; nbdev.nbdev_export()
