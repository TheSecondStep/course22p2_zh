# %%
#|default_exp augment

# %% [markdown]
# # Augmentation

# %%
import sys
sys.path.insert(0, "/home/tzyy/projects/course22p2_zh")

# %%
#|export
import torch,random
import fastcore.all as fc

from torch import nn
from torch.nn import init

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *
from miniai.sgd import *
from miniai.resnet import *

# %%
fc.defaults.cpus
# Out:
# 8

# %%
import pickle,gzip,math,os,time,shutil
import matplotlib as mpl,numpy as np,matplotlib.pyplot as plt
from collections.abc import Mapping
from pathlib import Path
from operator import attrgetter,itemgetter
from functools import partial
from copy import copy
from contextlib import contextmanager

import torchvision.transforms.functional as TF,torch.nn.functional as F
from torch import tensor,optim
from torch.utils.data import DataLoader,default_collate
from torch.optim import lr_scheduler
from torcheval.metrics import MulticlassAccuracy
from datasets import load_dataset,load_dataset_builder

from fastcore.test import test_close
from torch import distributions

torch.set_printoptions(precision=2, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'

import logging
logging.disable(logging.WARNING)

set_seed(42)

if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
fc.defaults.cpus=2

# %%
xl,yl = 'image','label'
name = "fashion_mnist"
bs = 1024
xmean,xstd = 0.28, 0.35

@inplace
def transformi(b): b[xl] = [(TF.to_tensor(o)-xmean)/xstd for o in b[xl]]

dsd = load_dataset(name)
tds = dsd.with_transform(transformi)
dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)

# %%
metrics = MetricsCB(accuracy=MulticlassAccuracy())
astats = ActivationStats(fc.risinstance(GeneralRelu))
cbs = [DeviceCB(), metrics, ProgressCB(plot=True), astats]
act_gr = partial(GeneralRelu, leak=0.1, sub=0.4)
iw = partial(init_weights, leaky=0.1)

# %%
set_seed(42)
lr,epochs = 6e-2,5

# %% [markdown]
# ## Going wider

# %%
def get_model(act=nn.ReLU, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %% [markdown]
# 为什么ks要从3变成5
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 这是一个很好的问题！注意看 `get_model` 里第一层和后续层的区别：
#
# ```python
# # 第一层：显式写了 ks=5
# layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
#
# # 后续层：没有写 ks，用的是 ResBlock 的默认值（通常是 3）
# layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
# ```
#
# 第一层用更大的 5×5 卷积核，原因有两点：
#
# 1. **感受野** — 第一层是整个网络接触原始图像的入口。用大一点的卷积核，每个神经元能"看到"更大的区域，捕捉更多纹理和边缘信息。后续层因为已经经过 stride=2 的下采样，特征图变小了，即使用 3×3 卷积核，感受野也已经足够大。
#
# 2. **适配图像尺寸** — Fashion-MNIST 是 28×28 的小图。标准 ResNet 针对 ImageNet（224×224）第一层用 7×7，但这里的图小得多，7×7 太大了会把细节"糊掉"，5×5 是个折中的选择。
#
# 简单说：**第一层要"看得广"，所以用 5×5；后面层已经通过下采样获得了足够大的感受野，用默认的 3×3 就够了。**
#
# 要不要试试把 `ks=5` 改回 3 跑一下，看看准确率有什么变化？
#
# <details class='token-usage-details' markdown='1'><summary>$0.0045</summary>
#
# `total=9,766 | in=8,840 | out=926 | cached=43.4% | reasoning=584 | searches=0 | $0.0045`
#
# </details>

# %% [markdown]
# 这是否是试验后的选择结果，还是理论上就可以区分3*3还是5*5效果好
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 这更偏向于**经验选择**，而非单纯靠理论就能严格推导出来的结果。理论能给你一些直觉方向，但最终拍板「3 还是 5」通常是靠实验比出来的。具体来说：
#
# **理论能告诉你的：**
#
# - 两个堆叠的 3×3 卷积，感受野等价于一个 5×5 卷积，但参数量更少（2×3²=18 vs 5²=25），非线性也更多 → 所以现在主流网络普遍用 3×3。
# - 但第一层是个例外——它面对的是原始像素，没有经过任何提炼，用一个稍大的卷积核直接"看宽一点"能捕捉更完整的低级特征（边缘、纹理走向），这算一个设计惯例。
#
# **理论无法告诉你的：**
#
# - 具体到 Fashion-MNIST 这个 28×28 的小图上，3 还是 5 效果更好？理论给不出精确答案，因为还要看数据集的纹理尺度、网络宽度、激活函数等等的交互。
# - 所以 5×5 这个值大概率是作者跑了几组对比实验后选出来的——可能试过 3、5、7，发现 5 在参数量和准确率之间折中最优。
#
# 总结一下：**理论告诉你"第一层可以考虑大一点的核"，但到底大多少，几乎总是靠实验决定。**
#
# <details class='token-usage-details' markdown='1'><summary>$0.0026</summary>
#
# `total=9,900 | in=9,257 | out=643 | cached=70.5% | reasoning=352 | searches=0 | $0.0026`
#
# </details>

# %%
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# %%
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.825</td><td>0.704</td><td>0</td><td>train</td></tr><tr><td>0.857</td><td>0.533</td><td>0</td><td>eval</td></tr><tr><td>0.898</td><td>0.382</td><td>1</td><td>train</td></tr><tr><td>0.896</td><td>0.352</td><td>1</td><td>eval</td></tr><tr><td>0.922</td><td>0.265</td><td>2</td><td>train</td></tr><tr><td>0.904</td><td>0.288</td><td>2</td><td>eval</td></tr><tr><td>0.941</td><td>0.197</td><td>3</td><td>train</td></tr><tr><td>0.928</td><td>0.236</td><td>3</td><td>eval</td></tr><tr><td>0.964</td><td>0.139</td><td>4</td><td>train</td></tr><tr><td>0.931</td><td>0.223</td><td>4</td><td>eval</td></tr></tbody></table></div>

# %%
def get_model(act=nn.ReLU, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=3, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# %%
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.814</td><td>0.648</td><td>0</td><td>train</td></tr><tr><td>0.840</td><td>0.481</td><td>0</td><td>eval</td></tr><tr><td>0.862</td><td>0.426</td><td>1</td><td>train</td></tr><tr><td>0.881</td><td>0.346</td><td>1</td><td>eval</td></tr><tr><td>0.890</td><td>0.331</td><td>2</td><td>train</td></tr><tr><td>0.861</td><td>0.382</td><td>2</td><td>eval</td></tr><tr><td>0.918</td><td>0.243</td><td>3</td><td>train</td></tr><tr><td>0.923</td><td>0.207</td><td>3</td><td>eval</td></tr><tr><td>0.947</td><td>0.159</td><td>4</td><td>train</td></tr><tr><td>0.935</td><td>0.184</td><td>4</td><td>eval</td></tr></tbody></table></div>

# %%
def get_model(act=nn.ReLU, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=7, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Flatten(), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# %%
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.811</td><td>0.653</td><td>0</td><td>train</td></tr><tr><td>0.841</td><td>0.489</td><td>0</td><td>eval</td></tr><tr><td>0.856</td><td>0.441</td><td>1</td><td>train</td></tr><tr><td>0.860</td><td>0.423</td><td>1</td><td>eval</td></tr><tr><td>0.886</td><td>0.344</td><td>2</td><td>train</td></tr><tr><td>0.900</td><td>0.276</td><td>2</td><td>eval</td></tr><tr><td>0.914</td><td>0.252</td><td>3</td><td>train</td></tr><tr><td>0.924</td><td>0.216</td><td>3</td><td>eval</td></tr><tr><td>0.942</td><td>0.171</td><td>4</td><td>train</td></tr><tr><td>0.932</td><td>0.189</td><td>4</td><td>eval</td></tr></tbody></table></div>

# %% [markdown]
# ### Pooling

# %%
class GlobalAvgPool(nn.Module):
    def forward(self, x): return x.mean((-2,-1))

# %%
def get_model2(act=nn.ReLU, nfs=(16,32,64,128,256), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [ResBlock(256, 512, act=act, norm=norm), GlobalAvgPool()]
    layers += [nn.Linear(512, 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
#|export
def _flops(x, h, w):
    if x.dim()<3: return x.numel()
    if x.dim()==4: return x.numel()*h*w

@fc.patch
def summary(self:Learner):
    res = '|Module|Input|Output|Num params|MFLOPS|\n|--|--|--|--|--|\n'
    totp,totf = 0,0
    def _f(hook, mod, inp, outp):
        nonlocal res,totp,totf
        nparms = sum(o.numel() for o in mod.parameters())
        totp += nparms
        *_,h,w = outp.shape
        flops = sum(_flops(o, h, w) for o in mod.parameters())/1e6
        totf += flops
        res += f'|{type(mod).__name__}|{tuple(inp[0].shape)}|{tuple(outp.shape)}|{nparms}|{flops:.1f}|\n'
    with Hooks(self.model, _f) as hooks: self.fit(1, lr=1, cbs=SingleBatchCB())
    print(f"Tot params: {totp}; MFLOPS: {totf:.1f}")
    if fc.IN_NOTEBOOK:
        from IPython.display import Markdown
        return Markdown(res)
    else: print(res)

# %%
TrainLearner(get_model2(), dls, F.cross_entropy, lr=lr, cbs=[DeviceCB()]).summary()
# Out:
# Tot params: 4907588; MFLOPS: 33.0
# |Module|Input|Output|Num params|MFLOPS|
# |--|--|--|--|--|
# |ResBlock|(1024, 1, 28, 28)|(1024, 16, 28, 28)|6928|5.3|
# |ResBlock|(1024, 16, 28, 28)|(1024, 32, 14, 14)|14560|2.8|
# |ResBlock|(1024, 32, 14, 14)|(1024, 64, 7, 7)|57792|2.8|
# |ResBlock|(1024, 64, 7, 7)|(1024, 128, 4, 4)|230272|3.7|
# |ResBlock|(1024, 128, 4, 4)|(1024, 256, 2, 2)|919296|3.7|
# |ResBlock|(1024, 256, 2, 2)|(1024, 512, 2, 2)|3673600|14.7|
# |GlobalAvgPool|(1024, 512, 2, 2)|(1024, 512)|0|0.0|
# |Linear|(1024, 512)|(1024, 10)|5120|0.0|
# |BatchNorm1d|(1024, 10)|(1024, 10)|20|0.0|

# %%
set_seed(42)
model = get_model2(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.822</td><td>0.714</td><td>0</td><td>train</td></tr><tr><td>0.855</td><td>0.554</td><td>0</td><td>eval</td></tr><tr><td>0.899</td><td>0.382</td><td>1</td><td>train</td></tr><tr><td>0.884</td><td>0.372</td><td>1</td><td>eval</td></tr><tr><td>0.921</td><td>0.268</td><td>2</td><td>train</td></tr><tr><td>0.908</td><td>0.292</td><td>2</td><td>eval</td></tr><tr><td>0.941</td><td>0.198</td><td>3</td><td>train</td></tr><tr><td>0.925</td><td>0.240</td><td>3</td><td>eval</td></tr><tr><td>0.962</td><td>0.141</td><td>4</td><td>train</td></tr><tr><td>0.930</td><td>0.227</td><td>4</td><td>eval</td></tr></tbody></table></div>

# %%
def get_model3(act=nn.ReLU, nfs=(16,32,64,128,256), norm=nn.BatchNorm2d):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [GlobalAvgPool(), nn.Linear(256, 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
TrainLearner(get_model3(), dls, F.cross_entropy, lr=lr, cbs=[DeviceCB()]).summary()
# Out:
# Tot params: 1231428; MFLOPS: 18.3
# |Module|Input|Output|Num params|MFLOPS|
# |--|--|--|--|--|
# |ResBlock|(1024, 1, 28, 28)|(1024, 16, 28, 28)|6928|5.3|
# |ResBlock|(1024, 16, 28, 28)|(1024, 32, 14, 14)|14560|2.8|
# |ResBlock|(1024, 32, 14, 14)|(1024, 64, 7, 7)|57792|2.8|
# |ResBlock|(1024, 64, 7, 7)|(1024, 128, 4, 4)|230272|3.7|
# |ResBlock|(1024, 128, 4, 4)|(1024, 256, 2, 2)|919296|3.7|
# |GlobalAvgPool|(1024, 256, 2, 2)|(1024, 256)|0|0.0|
# |Linear|(1024, 256)|(1024, 10)|2560|0.0|
# |BatchNorm1d|(1024, 10)|(1024, 10)|20|0.0|

# %%
get_model3()[0]
# Out:
# ResBlock(
#   (convs): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(16, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (idconv): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (act): ReLU()
# )

# %%
[o.shape for o in get_model3()[0].parameters()]
# Out:
# [torch.Size([16, 1, 5, 5]),
#  torch.Size([16]),
#  torch.Size([16]),
#  torch.Size([16]),
#  torch.Size([16, 16, 5, 5]),
#  torch.Size([16]),
#  torch.Size([16]),
#  torch.Size([16]),
#  torch.Size([16, 1, 1, 1]),
#  torch.Size([16])]

# %%
set_seed(42)
model = get_model3(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.810</td><td>0.758</td><td>0</td><td>train</td></tr><tr><td>0.864</td><td>0.456</td><td>0</td><td>eval</td></tr><tr><td>0.895</td><td>0.400</td><td>1</td><td>train</td></tr><tr><td>0.896</td><td>0.338</td><td>1</td><td>eval</td></tr><tr><td>0.920</td><td>0.275</td><td>2</td><td>train</td></tr><tr><td>0.899</td><td>0.312</td><td>2</td><td>eval</td></tr><tr><td>0.940</td><td>0.207</td><td>3</td><td>train</td></tr><tr><td>0.924</td><td>0.246</td><td>3</td><td>eval</td></tr><tr><td>0.961</td><td>0.151</td><td>4</td><td>train</td></tr><tr><td>0.928</td><td>0.232</td><td>4</td><td>eval</td></tr></tbody></table></div>

# %%
def get_model4(act=nn.ReLU, nfs=(16,32,64,128,256), norm=nn.BatchNorm2d):
    layers = [conv(1, 16, ks=5, stride=1, act=act, norm=norm)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [GlobalAvgPool(), nn.Linear(256, 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
[o.shape for o in get_model4()[0].parameters()]
# Out:
# [torch.Size([16, 1, 5, 5]),
#  torch.Size([16]),
#  torch.Size([16]),
#  torch.Size([16])]

# %%
TrainLearner(get_model4(), dls, F.cross_entropy, lr=lr, cbs=[DeviceCB()]).summary()
# Out:
# Tot params: 1224948; MFLOPS: 13.3
# |Module|Input|Output|Num params|MFLOPS|
# |--|--|--|--|--|
# |Sequential|(1024, 1, 28, 28)|(1024, 16, 28, 28)|448|0.3|
# |ResBlock|(1024, 16, 28, 28)|(1024, 32, 14, 14)|14560|2.8|
# |ResBlock|(1024, 32, 14, 14)|(1024, 64, 7, 7)|57792|2.8|
# |ResBlock|(1024, 64, 7, 7)|(1024, 128, 4, 4)|230272|3.7|
# |ResBlock|(1024, 128, 4, 4)|(1024, 256, 2, 2)|919296|3.7|
# |GlobalAvgPool|(1024, 256, 2, 2)|(1024, 256)|0|0.0|
# |Linear|(1024, 256)|(1024, 10)|2560|0.0|
# |BatchNorm1d|(1024, 10)|(1024, 10)|20|0.0|

# %%
set_seed(42)
model = get_model4(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.804</td><td>0.782</td><td>0</td><td>train</td></tr><tr><td>0.869</td><td>0.486</td><td>0</td><td>eval</td></tr><tr><td>0.897</td><td>0.392</td><td>1</td><td>train</td></tr><tr><td>0.895</td><td>0.352</td><td>1</td><td>eval</td></tr><tr><td>0.919</td><td>0.278</td><td>2</td><td>train</td></tr><tr><td>0.900</td><td>0.323</td><td>2</td><td>eval</td></tr><tr><td>0.940</td><td>0.203</td><td>3</td><td>train</td></tr><tr><td>0.923</td><td>0.246</td><td>3</td><td>eval</td></tr><tr><td>0.961</td><td>0.149</td><td>4</td><td>train</td></tr><tr><td>0.926</td><td>0.237</td><td>4</td><td>eval</td></tr></tbody></table></div>

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# After 20 epochs without augmentation:
#
# ```
# {'accuracy': '0.999', 'loss': '0.012', 'epoch': 19, 'train': True}
# {'accuracy': '0.924', 'loss': '0.284', 'epoch': 19, 'train': False}
# ```
#
# With batchnorm, weight decay doesn't really regularize.

# %%
from torchvision import transforms

# %%
def tfm_batch(b, tfm_x=fc.noop, tfm_y = fc.noop): return tfm_x(b[0]),tfm_y(b[1])

tfms = nn.Sequential(transforms.RandomCrop(28, padding=4),
                     transforms.RandomHorizontalFlip())

augcb = BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)
model = get_model()
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[SingleBatchCB(), augcb])

# %%
learn.fit(1)

# %%
xb,yb = learn.batch
show_images(xb[:16], imsize=1.5)

# %%
#| export
@fc.patch
@fc.delegates(show_images)
def show_image_batch(self:Learner, max_n=9, cbs=None, **kwargs):
    self.fit(1, cbs=[SingleBatchCB()]+fc.L(cbs))
    show_images(self.batch[0][:max_n], **kwargs)

# %%
learn.show_image_batch(max_n=16, imsize=(1.5))

# %%
tfms = nn.Sequential(transforms.RandomCrop(28, padding=1),
                     transforms.RandomHorizontalFlip())
augcb = BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)

# %%
set_seed(42)
epochs = 20
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched), augcb]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.764</td><td>0.879</td><td>0</td><td>train</td></tr><tr><td>0.826</td><td>0.600</td><td>0</td><td>eval</td></tr><tr><td>0.859</td><td>0.596</td><td>1</td><td>train</td></tr><tr><td>0.874</td><td>0.477</td><td>1</td><td>eval</td></tr><tr><td>0.877</td><td>0.478</td><td>2</td><td>train</td></tr><tr><td>0.858</td><td>0.463</td><td>2</td><td>eval</td></tr><tr><td>0.888</td><td>0.389</td><td>3</td><td>train</td></tr><tr><td>0.883</td><td>0.369</td><td>3</td><td>eval</td></tr><tr><td>0.895</td><td>0.336</td><td>4</td><td>train</td></tr><tr><td>0.887</td><td>0.351</td><td>4</td><td>eval</td></tr><tr><td>0.906</td><td>0.289</td><td>5</td><td>train</td></tr><tr><td>0.880</td><td>0.348</td><td>5</td><td>eval</td></tr><tr><td>0.914</td><td>0.256</td><td>6</td><td>train</td></tr><tr><td>0.902</td><td>0.280</td><td>6</td><td>eval</td></tr><tr><td>0.921</td><td>0.231</td><td>7</td><td>train</td></tr><tr><td>0.905</td><td>0.274</td><td>7</td><td>eval</td></tr><tr><td>0.923</td><td>0.224</td><td>8</td><td>train</td></tr><tr><td>0.913</td><td>0.249</td><td>8</td><td>eval</td></tr><tr><td>0.930</td><td>0.200</td><td>9</td><td>train</td></tr><tr><td>0.910</td><td>0.253</td><td>9</td><td>eval</td></tr><tr><td>0.935</td><td>0.188</td><td>10</td><td>train</td></tr><tr><td>0.925</td><td>0.214</td><td>10</td><td>eval</td></tr><tr><td>0.940</td><td>0.173</td><td>11</td><td>train</td></tr><tr><td>0.930</td><td>0.203</td><td>11</td><td>eval</td></tr><tr><td>0.944</td><td>0.162</td><td>12</td><td>train</td></tr><tr><td>0.924</td><td>0.216</td><td>12</td><td>eval</td></tr><tr><td>0.949</td><td>0.148</td><td>13</td><td>train</td></tr><tr><td>0.931</td><td>0.203</td><td>13</td><td>eval</td></tr><tr><td>0.952</td><td>0.138</td><td>14</td><td>train</td></tr><tr><td>0.936</td><td>0.191</td><td>14</td><td>eval</td></tr><tr><td>0.959</td><td>0.120</td><td>15</td><td>train</td></tr><tr><td>0.938</td><td>0.182</td><td>15</td><td>eval</td></tr><tr><td>0.963</td><td>0.111</td><td>16</td><td>train</td></tr><tr><td>0.940</td><td>0.180</td><td>16</td><td>eval</td></tr><tr><td>0.967</td><td>0.101</td><td>17</td><td>train</td></tr><tr><td>0.941</td><td>0.183</td><td>17</td><td>eval</td></tr><tr><td>0.970</td><td>0.093</td><td>18</td><td>train</td></tr><tr><td>0.940</td><td>0.183</td><td>18</td><td>eval</td></tr><tr><td>0.971</td><td>0.091</td><td>19</td><td>train</td></tr><tr><td>0.940</td><td>0.182</td><td>19</td><td>eval</td></tr></tbody></table></div>

# %% [markdown]
# A custom collation function could let you do per-item transformations.

# %%
mdl_path = Path('models')
mdl_path.mkdir(exist_ok=True)
torch.save(learn.model, mdl_path/'data_aug.pkl')

# %% [markdown]
# ## Test time augmentation (TTA)

# %%
#| export
class CapturePreds(Callback):
    def before_fit(self, learn): self.all_inps,self.all_preds,self.all_targs = [],[],[]
    def after_batch(self, learn):
        self.all_inps. append(to_cpu(learn.batch[0]))
        self.all_preds.append(to_cpu(learn.preds))
        self.all_targs.append(to_cpu(learn.batch[1]))
    def after_fit(self, learn):
        self.all_preds,self.all_targs,self.all_inps = map(torch.cat, [self.all_preds,self.all_targs,self.all_inps])

# %%
#| export
@fc.patch
def capture_preds(self: Learner, cbs=None, inps=False):
    cp = CapturePreds()
    self.fit(1, train=False, cbs=[cp]+fc.L(cbs))
    res = cp.all_preds,cp.all_targs
    if inps: res = res+(cp.all_inps,)
    return res

# %%
ap1, at = learn.capture_preds()
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.940</td><td>0.182</td><td>0</td><td>eval</td></tr></tbody></table></div>

# %%
ttacb = BatchTransformCB(partial(tfm_batch, tfm_x=TF.hflip), on_val=True)
ap2, at = learn.capture_preds(cbs=[ttacb])
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.943</td><td>0.180</td><td>0</td><td>eval</td></tr></tbody></table></div>

# %%
ap1.shape,ap2.shape,at.shape
# Out:
# (torch.Size([10000, 10]), torch.Size([10000, 10]), torch.Size([10000]))

# %%
ap = torch.stack([ap1,ap2]).mean(0).argmax(1)

# %%
round((ap==at).float().mean().item(), 3)
# Out:
# 0.944

# %% [markdown]
# ## Random erase

# %%
xb,_ = next(iter(dls.train))
xbt = xb[:16]

# %%
xm,xs = xbt.mean(),xbt.std()

# %%
xbt.min(), xbt.max()
# Out:
# (tensor(-0.80), tensor(2.06))

# %%
pct = 0.2

# %%
szx = int(pct*xbt.shape[-2])
szy = int(pct*xbt.shape[-1])
stx = int(random.random()*(1-pct)*xbt.shape[-2])
sty = int(random.random()*(1-pct)*xbt.shape[-1])
stx,sty,szx,szy
# Out:
# (14, 0, 5, 5)

# %%
init.normal_(xbt[:,:,stx:stx+szx,sty:sty+szy], mean=xm, std=xs);

# %%
show_images(xbt, imsize=1.5)

# %%
xbt.min(), xbt.max()
# Out:
# (tensor(-3.36), tensor(2.56))

# %%
#|export
def _rand_erase1(x, pct, xm, xs, mn, mx):
    szx = int(pct*x.shape[-2])
    szy = int(pct*x.shape[-1])
    stx = int(random.random()*(1-pct)*x.shape[-2])
    sty = int(random.random()*(1-pct)*x.shape[-1])
    init.normal_(x[:,:,stx:stx+szx,sty:sty+szy], mean=xm, std=xs)
    x.clamp_(mn, mx)

# %%
xb,_ = next(iter(dls.train))
xbt = xb[:16]
_rand_erase1(xbt, 0.2, xbt.mean(), xbt.std(), xbt.min(), xbt.max())
show_images(xbt, imsize=1.5)

# %%
xbt.mean(),xbt.std(),xbt.min(), xbt.max()
# Out:
# (tensor(0.09), tensor(1.04), tensor(-0.80), tensor(2.06))

# %%
#|export
def rand_erase(x, pct=0.2, max_num = 4):
    xm,xs,mn,mx = x.mean(),x.std(),x.min(),x.max()
    num = random.randint(0, max_num)
    for i in range(num): _rand_erase1(x, pct, xm, xs, mn, mx)
#     print(num)
    return x

# %%
xb,_ = next(iter(dls.train))
xbt = xb[:16]
rand_erase(xbt, 0.2, 4)
show_images(xbt, imsize=1.5)

# %%
#|export
class RandErase(nn.Module):
    def __init__(self, pct=0.2, max_num=4):
        super().__init__()
        self.pct,self.max_num = pct,max_num
    def forward(self, x): return rand_erase(x, self.pct, self.max_num)

# %%
tfms = nn.Sequential(transforms.RandomCrop(28, padding=1),
                     transforms.RandomHorizontalFlip(),
                     RandErase())
augcb = BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)

# %%
model = get_model()
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[DeviceCB(), SingleBatchCB(), augcb])
learn.fit(1)
xb,yb = learn.batch
show_images(xb[:16], imsize=1.5)

# %%
epochs = 50
lr = 2e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched), augcb]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>accuracy</th><th>loss</th><th>epoch</th><th>train</th></tr></thead><tbody><tr><td>0.756</td><td>0.888</td><td>0</td><td>train</td></tr><tr><td>0.832</td><td>0.581</td><td>0</td><td>eval</td></tr><tr><td>0.844</td><td>0.621</td><td>1</td><td>train</td></tr><tr><td>0.857</td><td>0.537</td><td>1</td><td>eval</td></tr><tr><td>0.864</td><td>0.531</td><td>2</td><td>train</td></tr><tr><td>0.870</td><td>0.433</td><td>2</td><td>eval</td></tr><tr><td>0.872</td><td>0.460</td><td>3</td><td>train</td></tr><tr><td>0.874</td><td>0.425</td><td>3</td><td>eval</td></tr><tr><td>0.879</td><td>0.404</td><td>4</td><td>train</td></tr><tr><td>0.883</td><td>0.359</td><td>4</td><td>eval</td></tr><tr><td>0.881</td><td>0.371</td><td>5</td><td>train</td></tr><tr><td>0.859</td><td>0.434</td><td>5</td><td>eval</td></tr><tr><td>0.884</td><td>0.349</td><td>6</td><td>train</td></tr><tr><td>0.840</td><td>0.477</td><td>6</td><td>eval</td></tr><tr><td>0.888</td><td>0.328</td><td>7</td><td>train</td></tr><tr><td>0.890</td><td>0.319</td><td>7</td><td>eval</td></tr><tr><td>0.901</td><td>0.284</td><td>8</td><td>train</td></tr><tr><td>0.905</td><td>0.270</td><td>8</td><td>eval</td></tr><tr><td>0.903</td><td>0.276</td><td>9</td><td>train</td></tr><tr><td>0.851</td><td>0.446</td><td>9</td><td>eval</td></tr><tr><td>0.899</td><td>0.283</td><td>10</td><td>train</td></tr><tr><td>0.891</td><td>0.312</td><td>10</td><td>eval</td></tr><tr><td>0.903</td><td>0.272</td><td>11</td><td>train</td></tr><tr><td>0.910</td><td>0.245</td><td>11</td><td>eval</td></tr><tr><td>0.905</td><td>0.262</td><td>12</td><td>train</td></tr><tr><td>0.860</td><td>0.400</td><td>12</td><td>eval</td></tr><tr><td>0.909</td><td>0.254</td><td>13</td><td>train</td></tr><tr><td>0.885</td><td>0.345</td><td>13</td><td>eval</td></tr><tr><td>0.912</td><td>0.241</td><td>14</td><td>train</td></tr><tr><td>0.904</td><td>0.274</td><td>14</td><td>eval</td></tr><tr><td>0.919</td><td>0.227</td><td>15</td><td>train</td></tr><tr><td>0.914</td><td>0.237</td><td>15</td><td>eval</td></tr><tr><td>0.921</td><td>0.219</td><td>16</td><td>train</td></tr><tr><td>0.903</td><td>0.273</td><td>16</td><td>eval</td></tr><tr><td>0.922</td><td>0.215</td><td>17</td><td>train</td></tr><tr><td>0.912</td><td>0.245</td><td>17</td><td>eval</td></tr><tr><td>0.925</td><td>0.207</td><td>18</td><td>train</td></tr><tr><td>0.916</td><td>0.242</td><td>18</td><td>eval</td></tr><tr><td>0.925</td><td>0.206</td><td>19</td><td>train</td></tr><tr><td>0.913</td><td>0.242</td><td>19</td><td>eval</td></tr><tr><td>0.926</td><td>0.201</td><td>20</td><td>train</td></tr><tr><td>0.927</td><td>0.204</td><td>20</td><td>eval</td></tr><tr><td>0.930</td><td>0.192</td><td>21</td><td>train</td></tr><tr><td>0.917</td><td>0.228</td><td>21</td><td>eval</td></tr><tr><td>0.931</td><td>0.189</td><td>22</td><td>train</td></tr><tr><td>0.915</td><td>0.242</td><td>22</td><td>eval</td></tr><tr><td>0.932</td><td>0.184</td><td>23</td><td>train</td></tr><tr><td>0.922</td><td>0.234</td><td>23</td><td>eval</td></tr><tr><td>0.932</td><td>0.187</td><td>24</td><td>train</td></tr><tr><td>0.931</td><td>0.194</td><td>24</td><td>eval</td></tr><tr><td>0.938</td><td>0.171</td><td>25</td><td>train</td></tr><tr><td>0.932</td><td>0.192</td><td>25</td><td>eval</td></tr><tr><td>0.940</td><td>0.166</td><td>26</td><td>train</td></tr><tr><td>0.909</td><td>0.249</td><td>26</td><td>eval</td></tr><tr><td>0.940</td><td>0.164</td><td>27</td><td>train</td></tr><tr><td>0.925</td><td>0.209</td><td>27</td><td>eval</td></tr><tr><td>0.940</td><td>0.161</td><td>28</td><td>train</td></tr><tr><td>0.924</td><td>0.211</td><td>28</td><td>eval</td></tr><tr><td>0.945</td><td>0.152</td><td>29</td><td>train</td></tr><tr><td>0.935</td><td>0.182</td><td>29</td><td>eval</td></tr><tr><td>0.946</td><td>0.147</td><td>30</td><td>train</td></tr><tr><td>0.935</td><td>0.193</td><td>30</td><td>eval</td></tr><tr><td>0.950</td><td>0.140</td><td>31</td><td>train</td></tr><tr><td>0.935</td><td>0 ...

# %% [markdown]
# ## Random copy

# %%
xb,_ = next(iter(dls.train))
xbt = xb[:16]

# %%
szx = int(pct*xbt.shape[-2])
szy = int(pct*xbt.shape[-1])
stx1 = int(random.random()*(1-pct)*xbt.shape[-2])
sty1 = int(random.random()*(1-pct)*xbt.shape[-1])
stx2 = int(random.random()*(1-pct)*xbt.shape[-2])
sty2 = int(random.random()*(1-pct)*xbt.shape[-1])
stx1,sty1,stx2,sty2,szx,szy
# Out:
# (1, 6, 21, 3, 5, 5)

# %%
xbt[:,:,stx1:stx1+szx,sty1:sty1+szy] = xbt[:,:,stx2:stx2+szx,sty2:sty2+szy]

# %%
show_images(xbt, imsize=1.5)

# %%
#|export
def _rand_copy1(x, pct):
    szx = int(pct*x.shape[-2])
    szy = int(pct*x.shape[-1])
    stx1 = int(random.random()*(1-pct)*x.shape[-2])
    sty1 = int(random.random()*(1-pct)*x.shape[-1])
    stx2 = int(random.random()*(1-pct)*x.shape[-2])
    sty2 = int(random.random()*(1-pct)*x.shape[-1])
    x[:,:,stx1:stx1+szx,sty1:sty1+szy] = x[:,:,stx2:stx2+szx,sty2:sty2+szy]

# %%
xb,_ = next(iter(dls.train))
xbt = xb[:16]
_rand_copy1(xbt, 0.2)
show_images(xbt, imsize=1.5)

# %%
#|export
def rand_copy(x, pct=0.2, max_num = 4):
    num = random.randint(0, max_num)
    for i in range(num): _rand_copy1(x, pct)
#     print(num)
    return x

# %%
xb,_ = next(iter(dls.train))
xbt = xb[:16]
rand_copy(xbt, 0.2, 4)
show_images(xbt, imsize=1.5)

# %%
#|export
class RandCopy(nn.Module):
    def __init__(self, pct=0.2, max_num=4):
        super().__init__()
        self.pct,self.max_num = pct,max_num
    def forward(self, x): return rand_copy(x, self.pct, self.max_num)

# %%
tfms = nn.Sequential(transforms.RandomCrop(28, padding=1),
                     transforms.RandomHorizontalFlip(),
                     RandCopy())
augcb = BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)

# %%
model = get_model()
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=[DeviceCB(), SingleBatchCB(), augcb])
learn.fit(1)
xb,yb = learn.batch
show_images(xb[:16], imsize=1.5)

# %%
set_seed(1)
epochs = 25
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched), augcb]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.734</td>
#       <td>0.945</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.802</td>
#       <td>0.641</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.832</td>
#       <td>0.667</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.833</td>
#       <td>0.570</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.846</td>
#       <td>0.577</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.855</td>
#       <td>0.459</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.859</td>
#       <td>0.487</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.849</td>
#       <td>0.477</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.870</td>
#       <td>0.421</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.868</td>
#       <td>0.387</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.880</td>
#       <td>0.369</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.820</td>
#       <td>0.487</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.885</td>
#       <td>0.340</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.888</td>
#       <td>0.317</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.895</td>
#       <td>0.304</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.881</td>
#       <td>0.350</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.903</td>
#       <td>0.281</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.894</td>
#       <td>0.305</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.906</td>
#       <td>0.268</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.908</td>
#       <td>0.265</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.253</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.909</td>
#       <td>0.253</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.916</td>
#       <td>0.234</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.238</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.919</td>
#       <td>0.230</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.907</td>
#       <td>0.256</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.219</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.915</td>
#       <td>0.240</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.929</td>
#       <td>0.200</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.244</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.201</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.194</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.186</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.195</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.938</td>
#       <td>0.177</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.931</td>
#       <td>0.197</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.940</td>
#       <td>0.168</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.184</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.947</td>
#       <td>0.151</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.939</td>
#       <td>0.173</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.949</td>
#       <td>0.144</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.940</td>
#       <td>0.169</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.950</td>
#       <td>0.143</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.943</td>
#       <td>0.168</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.953</td>
#       <td>0.134</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.943</td>
#       <td>0.167</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.953</td>
#       <td>0.132</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.945</td>
#       <td>0.164</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.954</td>
#       <td>0.132</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.944</td>
#       <td>0.163</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
model2 = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn2 = TrainLearner(model2, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn2.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.743</td>
#       <td>0.932</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.807</td>
#       <td>0.621</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.831</td>
#       <td>0.670</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.823</td>
#       <td>0.585</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.854</td>
#       <td>0.558</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.855</td>
#       <td>0.480</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.865</td>
#       <td>0.478</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.875</td>
#       <td>0.404</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.876</td>
#       <td>0.402</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.882</td>
#       <td>0.366</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.877</td>
#       <td>0.377</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.884</td>
#       <td>0.350</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.890</td>
#       <td>0.327</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.904</td>
#       <td>0.281</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.899</td>
#       <td>0.296</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.885</td>
#       <td>0.328</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.903</td>
#       <td>0.281</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.886</td>
#       <td>0.333</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.908</td>
#       <td>0.266</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.901</td>
#       <td>0.278</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.916</td>
#       <td>0.240</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.912</td>
#       <td>0.249</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.920</td>
#       <td>0.227</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.909</td>
#       <td>0.257</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.220</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.240</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.926</td>
#       <td>0.207</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.246</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.203</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.917</td>
#       <td>0.233</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.930</td>
#       <td>0.195</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.223</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.935</td>
#       <td>0.182</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.932</td>
#       <td>0.202</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.176</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.188</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.939</td>
#       <td>0.172</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.935</td>
#       <td>0.186</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.943</td>
#       <td>0.162</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.938</td>
#       <td>0.177</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.946</td>
#       <td>0.150</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.939</td>
#       <td>0.177</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.950</td>
#       <td>0.139</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.941</td>
#       <td>0.170</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.952</td>
#       <td>0.138</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.941</td>
#       <td>0.171</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.954</td>
#       <td>0.134</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.942</td>
#       <td>0.169</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.954</td>
#       <td>0.131</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.944</td>
#       <td>0.166</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
mdl_path = Path('models')
torch.save(learn.model,  mdl_path/'randcopy1.pkl')
torch.save(learn2.model, mdl_path/'randcopy2.pkl')

# %%
cp1 = CapturePreds()
learn.fit(1, train=False, cbs=cp1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.944</td>
#       <td>0.163</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
cp2 = CapturePreds()
learn2.fit(1, train=False, cbs=cp2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.944</td>
#       <td>0.166</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
ap = torch.stack([cp1.all_preds,cp2.all_preds]).mean(0).argmax(1)

# %%
round((ap==cp1.all_targs).float().mean().item(), 3)
# Out:
# 0.947

# %% [markdown]
# ## Dropout

# %%
p = 0.1
dist = distributions.binomial.Binomial(probs=1-p)
dist.sample((10,))
# Out:
# tensor([1., 0., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
class Dropout(nn.Module):
    def __init__(self, p=0.1):
        super().__init__()
        self.p = p

    def forward(self, x):
        if not self.training: return x
        dist = distributions.binomial.Binomial(tensor(1.0).to(x.device), probs=1-self.p)
        return x * dist.sample(x.size()) * 1/(1-self.p)

# %%
def get_dropmodel(act=nn.ReLU, nfs=(16,32,64,128,256,512), norm=nn.BatchNorm2d, drop=0.0):
    layers = [ResBlock(1, 16, ks=5, stride=1, act=act, norm=norm), nn.Dropout2d(drop)]
    layers += [ResBlock(nfs[i], nfs[i+1], act=act, norm=norm, stride=2) for i in range(len(nfs)-1)]
    layers += [nn.Flatten(), Dropout(drop), nn.Linear(nfs[-1], 10, bias=False), nn.BatchNorm1d(10)]
    return nn.Sequential(*layers)

# %%
set_seed(42)
epochs=5
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)]
model = get_dropmodel(act_gr, norm=nn.BatchNorm2d, drop=0.1).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)

# %%
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.809</td>
#       <td>0.746</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.829</td>
#       <td>0.557</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.892</td>
#       <td>0.396</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.882</td>
#       <td>0.350</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.916</td>
#       <td>0.280</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.284</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.209</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.924</td>
#       <td>0.242</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.956</td>
#       <td>0.157</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.932</td>
#       <td>0.223</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
class TTD_CB(Callback):
    def before_epoch(self, learn):
        learn.model.apply(lambda m: m.train() if isinstance(m, (nn.Dropout,nn.Dropout2d)) else None)

# %% [markdown]
# ## Augment 2

# %%
@inplace
def transformi(b): b[xl] = [(TF.to_tensor(o)*2-1) for o in b[xl]]

tds = dsd.with_transform(transformi)
dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)

# %%
set_seed(42)
epochs = 20
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched), augcb]
model = get_model(act_gr, norm=nn.BatchNorm2d).apply(iw)
learn = TrainLearner(model, dls, F.cross_entropy, lr=lr, cbs=cbs+xtra, opt_func=optim.AdamW)
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.762</td>
#       <td>0.885</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.826</td>
#       <td>0.592</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.853</td>
#       <td>0.608</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.851</td>
#       <td>0.511</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.869</td>
#       <td>0.494</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.867</td>
#       <td>0.409</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.883</td>
#       <td>0.402</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.885</td>
#       <td>0.355</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.894</td>
#       <td>0.337</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.843</td>
#       <td>0.457</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.901</td>
#       <td>0.300</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.859</td>
#       <td>0.402</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.260</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.901</td>
#       <td>0.292</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.918</td>
#       <td>0.240</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.891</td>
#       <td>0.320</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.923</td>
#       <td>0.224</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.904</td>
#       <td>0.270</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.929</td>
#       <td>0.204</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.907</td>
#       <td>0.265</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.935</td>
#       <td>0.189</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.906</td>
#       <td>0.269</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.184</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.923</td>
#       <td>0.223</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.942</td>
#       <td>0.167</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.919</td>
#       <td>0.225</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.947</td>
#       <td>0.153</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.209</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.953</td>
#       <td>0.136</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.196</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.957</td>
#       <td>0.125</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.186</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.961</td>
#       <td>0.114</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.938</td>
#       <td>0.179</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.965</td>
#       <td>0.104</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.939</td>
#       <td>0.185</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.968</td>
#       <td>0.096</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.941</td>
#       <td>0.180</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.971</td>
#       <td>0.091</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.941</td>
#       <td>0.177</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
torch.save(learn.model, 'models/data_aug2.pkl')

# %% [markdown]
# ### Export -

# %%
import nbdev; nbdev.nbdev_export()
